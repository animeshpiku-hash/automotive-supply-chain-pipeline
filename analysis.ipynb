# %%
print("🚀 Supply Chain Project Started")
# Out:
# 🚀 Supply Chain Project Started

# %%
import os

print("Files in data folder:")
print(os.listdir("data"))
# Out:
# Files in data folder:
# ['.gitkeep']

# %%
import os
os.listdir("data")
# Out:
# ['.gitkeep']

# %%
import os
os.listdir("data")
# Out:
# ['.gitkeep']

# %%
import pandas as pd

df = pd.read_csv("data/supplier_delivery.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("data/supplier_delivery.csv")
#       4 df.head()
#
# ModuleNotFoundError: No module named 'pandas'
